# %% [markdown]
# ---
# title: "Stand Up Comedy"
# description: "is AI funny?"
# author: "Angelica"
# date: "11/01/2025"
# categories:
#   - LLMs
#   - Prompting
# ---

# %% [markdown]
# <img src="comedy.jpg" width="50%"/>

# %% [markdown]
# As we know, a big reason why AI cannot compare to humans is being that it lacks personality and creativity. In class, we looked at workflow models and how they work, prompting it to tell us jokes about Penn. This made me think, with a little bit of help, could an LLM be funny?

# %% [markdown]
# Here's what I asked anthropic/claude-3.7: "Let’s create a comedy show together that will amuse Gen-Z. Use jokes like 6/7, Madame Morrable flip it around wicked witch, and other brainrot found on tiktok." The response...?

# %%
from IPython.display import display, Markdown, HTML

# Define custom CSS for styling
css = """
<style>
    .comedy-script {
        font-family: 'Courier New', monospace;
        background: white;
        padding: 40px;
        border: 2px solid #333;
        color: black;
        max-width: 800px;
        margin: 20px auto;
        box-shadow: 0 5px 15px rgba(0,0,0,0.1);
    }
    .comedy-script h1 {
        text-align: center;
        font-size: 2em;
        margin-bottom: 5px;
        text-transform: uppercase;
        border-bottom: 3px double #000;
        padding-bottom: 15px;
    }
    .comedy-script h2 {
        text-align: center;
        padding: 10px;
        margin-top: 40px;
        margin-bottom: 20px;
        font-size: 1.3em;
        text-transform: uppercase;
        border-top: 1px solid #000;
        border-bottom: 1px solid #000;
    }
    .character {
        color: black;
        font-weight: bold;
        margin-top: 20px;
        margin-left: 200px;
        text-transform: uppercase;
    }
    .stage-direction {
        color: #333;
        font-style: italic;
        margin: 15px 0;
        margin-left: 100px;
        margin-right: 100px;
    }
    .dialogue {
        margin-left: 100px;
        margin-right: 100px;
        line-height: 1.8;
        text-align: justify;
    }
    .sponsor {
        text-decoration: underline;
    }
</style>
"""

# HTML formatted script
script_html = """
<div class="comedy-script">
    <h1>"UNHINGED: The Gen Z Experience"</h1>
    
    <h2>Scene 1: The Vibe Check</h2>
    <p class="stage-direction">(Two hosts, ALEX and JORDAN, sit on bean bags in a chaotically decorated set with LED lights and random objects like a giant rubber duck)</p>
    
    <p class="character">Alex</p>
    <p class="dialogue">Welcome to UNHINGED, where we're serving nothing but vibes and emotional damage!</p>
    
    <p class="character">Jordan</p>
    <p class="dialogue">I'm Jordan, my pronouns are they/them, and I haven't known peace since 2016.</p>
    
    <p class="character">Alex</p>
    <p class="dialogue">And I'm Alex, living proof that trauma and comedy are basically the same thing. Today's episode is <span class="sponsor">sponsored by my crippling student debt!</span></p>
    
    <p class="character">Jordan</p>
    <p class="dialogue">6 out of 7 doctors recommend watching our show. The 7th one is my ex, and they're just being petty.</p>
    
    <p class="character">Alex</p>
    <p class="dialogue">Speaking of numbers that don't add up, let's talk about how I spent $50 on iced coffee this week but can't afford therapy!</p>
    
    <h2>Scene 2: Theatre Kid Takeover</h2>
    <p class="stage-direction">(JORDAN puts on a comically large witch hat)</p>
    
    <p class="character">Jordan</p>
    <p class="dialogue">You know what's wild? In Wicked, Madame Morrible is basically the villain, but flip it around and the "wicked" witch is actually the good one. My brain is literally broken.</p>
    
    <p class="character">Alex</p>
    <p class="dialogue">That's giving very much "the real villain was capitalism all along" energy.</p>
    
    <p class="character">Jordan</p>
    <p class="dialogue"><em>(dramatically)</em> No one mourns the student loans!</p>
    
    <h2>Scene 3: Terminally Online</h2>
    
    <p class="character">Alex</p>
    <p class="dialogue"><em>(scrolling phone)</em> I just spent three hours in a TikTok hole watching people organize their refrigerators. This is my villain origin story.</p>
    
    <p class="character">Jordan</p>
    <p class="dialogue">That's so valid. I stayed up until 4 AM watching people react to other people reacting to other people reacting to a 10-second clip.</p>
    
    <p class="character">Alex</p>
    <p class="dialogue">The algorithm knows me better than my own mother at this point. It's giving parasocial relationship.</p>
    
    <p class="character">Jordan</p>
    <p class="dialogue">Not the algorithm exposing your childhood trauma! I'm deceased! 💀</p>
</div>
"""

# Display the styled script
display(HTML(css + script_html))
# Out:
# <style>
#     .comedy-script {
#         font-family: 'Courier New', monospace;
#         background: white;
#         padding: 40px;
#         border: 2px solid #333;
#         color: black;
#         max-width: 800px;
#         margin: 20px auto;
#         box-shadow: 0 5px 15px rgba(0,0,0,0.1);
#     }
#     .comedy-script h1 {
#         text-align: center;
#         font-size: 2em;
#         margin-bottom: 5px;
#         text-transform: uppercase;
#         border-bottom: 3px double #000;
#         padding-bottom: 15px;
#     }
#     .comedy-script h2 {
#         text-align: center;
#         padding: 10px;
#         margin-top: 40px;
#         margin-bottom: 20px;
#         font-size: 1.3em;
#         text-transform: uppercase;
#         border-top: 1px solid #000;
#         border-bottom: 1px solid #000;
#     }
#     .character {
#         color: black;
#         font-weight: bold;
#         margin-top: 20px;
#         margin-left: 200px;
#         text-transform: uppercase;
# ...

# %% [markdown]
# While I did find myself chuckling at a few of the jokes made in this script (maybe because they were so bad), it doesn't seem like the LLM understood some of the jokes that I was asking it to make. Generation Z has a very specific type of humor - that is, most jokes have no reasoning behind them or seem to make sense. It's more of a "if you know, you know" kind of situation which is why perhaps AI was off. For instance, instead of saying "I'm deceased!" the average Gen-Zer would have said "I'm dead!" Perhaps that isn't too appropraite here and the LLM is trying to stay censored. What if we asked it to make humor according to millenials?

# %%
from IPython.display import display, Markdown, HTML

# Define custom CSS for styling
css = """
<style>
    .comedy-script {
        font-family: 'Courier New', monospace;
        background: white;
        padding: 40px;
        border: 2px solid #333;
        color: black;
        max-width: 800px;
        margin: 20px auto;
        box-shadow: 0 5px 15px rgba(0,0,0,0.1);
    }
    .comedy-script h1 {
        text-align: center;
        font-size: 2em;
        margin-bottom: 5px;
        text-transform: uppercase;
        border-bottom: 3px double #000;
        padding-bottom: 15px;
    }
    .comedy-script h2 {
        text-align: center;
        padding: 10px;
        margin-top: 40px;
        margin-bottom: 20px;
        font-size: 1.3em;
        text-transform: uppercase;
        border-top: 1px solid #000;
        border-bottom: 1px solid #000;
    }
    .character {
        color: black;
        font-weight: bold;
        margin-top: 20px;
        margin-left: 200px;
        text-transform: uppercase;
    }
    .stage-direction {
        color: #333;
        font-style: italic;
        margin: 15px 0;
        margin-left: 100px;
        margin-right: 100px;
    }
    .dialogue {
        margin-left: 100px;
        margin-right: 100px;
        line-height: 1.8;
        text-align: justify;
    }
    .set-change {
        color: #333;
        font-style: italic;
        margin: 20px 0;
        text-align: center;
        text-decoration: underline;
    }
</style>
"""

# HTML formatted script
script_html = """
<div class="comedy-script">
    <h1>"Adulting Adjacent: A Millennial Experience"</h1>
    
    <h2>Scene 1: The Morning Ritual</h2>
    <p class="stage-direction">(TAYLOR and MORGAN stand in a kitchen with avocado toast, cold brew coffee, and plants everywhere. Both look perpetually tired but are trying very hard.)</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue"><em>(staring at phone)</em> Welcome to "Adulting Adjacent," the show where we pretend to have our lives together while our retirement plans consist entirely of hoping the world ends before we need to cash in.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue">I'm Morgan, and this morning I put my keys in the refrigerator, my almond milk in my bag, and had a full existential crisis before 8 AM.</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue">And I'm Taylor. I just paid my rent and celebrated by eating ramen for the fifth night in a row. But it's the fancy ramen with an egg on top, so basically I'm a chef.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue"><em>(raises coffee)</em> Here's to being old enough to get excited about new sponges but young enough to still not understand how to file taxes!</p>
    
    <h2>Scene 2: The Office Space</h2>
    <p class="set-change">Set changes to a bland office with motivational posters and succulents on desks</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue"><em>(typing aggressively)</em> Nothing says "I'm dead inside" like replying "per my last email" when what you really want to say is "can you read, Karen?"</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue"><em>(nodding)</em> This morning my boss said "let's circle back" and "touch base" in the same sentence, and I had to physically restrain myself from flipping the conference table.</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue">Last week, I got excited because the company ordered the good coffee for the break room. This is what my life has become. My childhood dream was to be an astronaut, and now I celebrate coffee that doesn't taste like dirt.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue">Remember when we thought adults had it all figured out? <em>(laughs hysterically, then suddenly stops)</em> I found a gray hair yesterday and had to lie down for an hour.</p>
    
    <h2>Scene 3: The Social Media Spiral</h2>
    <p class="stage-direction">(Both sitting on a couch, scrolling phones)</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue">So my high school bully just bought her third house, and I'm over here debating if I should splurge on name-brand cereal.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue">I just spent 40 minutes looking at pictures of a destination wedding for someone I haven't spoken to since 2011. Why am I like this?</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue">Yesterday I got genuinely angry that no one liked my Instagram story about my new air fryer. I've become everything I used to mock.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue">Speaking of which, have I told you about my air fryer? It's literally changed my life. <em>(pulls out phone)</em> Look at these sweet potato fries!</p>
    
    <h2>Scene 4: Nostalgia Overload</h2>
    <p class="set-change">Set decorated with 90s memorabilia</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue"><em>(holding up a Tamagotchi)</em> Remember when our biggest responsibility was keeping these alive? Now I have plants, a cat, and crushing student debt to keep alive.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue">I found my old Blockbuster card while moving apartments, and I genuinely got emotional. Now we have 17 streaming services and still nothing to watch.</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue">I told my niece I used to record songs off the radio onto cassette tapes, and she asked me what all of those words meant.</p>
    
    <p class="character">Morgan</p>
    <p class="dialogue"><em>(singing)</em> 🎵 I don't want no scrub, a scrub is a guy that can't get no love from me... 🎵</p>
    
    <p class="character">Taylor</p>
    <p class="dialogue"><em>(joining in)</em> 🎵 Hanging out the passenger side of his best friend's ride, trying to holler at me!</p>
</div>
"""

# Display the styled script
display(HTML(css + script_html))
# Out:
# <style>
#     .comedy-script {
#         font-family: 'Courier New', monospace;
#         background: white;
#         padding: 40px;
#         border: 2px solid #333;
#         color: black;
#         max-width: 800px;
#         margin: 20px auto;
#         box-shadow: 0 5px 15px rgba(0,0,0,0.1);
#     }
#     .comedy-script h1 {
#         text-align: center;
#         font-size: 2em;
#         margin-bottom: 5px;
#         text-transform: uppercase;
#         border-bottom: 3px double #000;
#         padding-bottom: 15px;
#     }
#     .comedy-script h2 {
#         text-align: center;
#         padding: 10px;
#         margin-top: 40px;
#         margin-bottom: 20px;
#         font-size: 1.3em;
#         text-transform: uppercase;
#         border-top: 1px solid #000;
#         border-bottom: 1px solid #000;
#     }
#     .character {
#         color: black;
#         font-weight: bold;
#         margin-top: 20px;
#         margin-left: 200px;
#         text-transform: uppercase;
# ...

# %% [markdown]
# I wonder if Millennials would be offended by some of these jokes. I guess stand up comedy is just making relatable jokes, but wha
