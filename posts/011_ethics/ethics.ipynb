# %% [markdown]
# ---
# title: "Should we care about ethics?"
# description: "a harsh reality"
# author: "Angelica Hu"
# date: "11/05/2025"
# categories:
# - LLMs
# - ethics
# - prompting
# ---

# %%
draft = "false"

# %% [markdown]
# <img src = "ethics.jpg" width=400>

# %% [markdown]
# A harsh reality of growing up is realizing that sadly, we live in a capitalistic society and oftentimes many people in power only care about profit and becoming wealthier. While I agree financial stability and economic security is important for individuals, at what point is it enough?
