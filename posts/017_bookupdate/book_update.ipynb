# %% [markdown]
# ---
# title: "A Revelation From Unmasking AI: Transparency"
# description: "the encoding bias"
# author: "Angelica Hu"
# date: "12/02/2025"
# categories:
# - prompting
# - LLMs
# - Unmasking AI
# ---
