# %% [markdown]
# ---
# title: "The Algorithmic Justice League"
# description: "Dr. Joy Buolamwini's Mission"
# author: "Angelica Hu"
# date: "12/02/2025"
# categories:
# - Prompting
# - LLMs
# - Living With a Book
# ---

# %% [markdown]
# <img src = "AJL.png" width=250>

# %% [markdown]
# Continuing to read Unmasking AI, by Dr. Joy Buolamwini, I've become more astonished by her work with digital social justice. By bringing to light the harms of algorithmic bias that often many choose to ignore when measuring the benefits of AI, Buolamwini is forcing companies to have some accountability for the harms that they inflict.

# %% [markdown]
# Compiling her work to found the Algorithmic Justice League (AJL), I wanted to continue exploring her work outside of the novel. What I was lead to was her more than established webiste.

# %% [markdown]
# <img src="image1.jpg" width="100%"/>

# %% [markdown]
# <img src="image2.jpg" width="100%"/>

# %% [markdown]
# <img src="image3.jpg" width="100%"/>

# %% [markdown]
# Seeing the legitmacy of her many years of work compiled into one place is extremeley inspiring. She is a prime example of how passion can take you far. One thing she mentions in her book, is how she was sometimes challenged by others to focus on doing more good than critizing what already exists. However, in critizing what exists, she does good as bringing attention to these harms is what creates true change in the digitial world.

# %% [markdown]
# Upon entering the website, you are also guided to expore the Coded Bias film - where essentially Buolamwini puts her research or narrative into a documentary film. This is something that I would enjoy watching to supplemnt my learnings and findings of this book.

# %% [markdown]
# By being able to capture the attention of audiences, the general public, and stakeholders, Joy Buolamwini shows the power that a single individual could have in creating change. It's cool to see how this movement has picked up momentum just over the past decade as technology continues to advance, making these disparities that are present even more important to address. Looking at the pieces of work she mentions in her book, such as Gendered Shades or her poem in physical form is super cool to see as well. She has dedicated her life's work to ensuring social progress.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('QxuyfWoVV98')

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('TWWsW1w-BVo')
